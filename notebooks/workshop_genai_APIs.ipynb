# %% [markdown]
# # Github repo: https://github.com/jusbraun/genai_classifier_dataharvest

# %% [markdown]
# ## When should we be using LLMs?
# 1. When I can tell when it's wrong: simple coding tasks (instant feedback)
# 2. When it doesn't matter that it's wrong: summary of unimportant meeting that I will probably never look at again.
#
# When neither of these conditions are met, it's important to set up your pipeline so you can evaluate the error rate. This requires, to constrain the LLM's choices, ensure that it sticks to the provided options, and a hand-labelled test set against which you can benchmark the performance of the LLM.
#
# But it's always worth asking: Can I regex this? Or is there some other kind of deterministic rule set I can use to get to the same result? When you have the option, it's always better to use an approach where you fully understand every step along the way!!!

# %% [markdown]
# ## Using LLM APIs
# ### OLLAMA
# Ollama allows you to run various LLMs locally on your machine. This includes models optimzed for text-only tasks (e.g., Llama 3 as well as multimodal models (llava).
# 1. Download Ollama at https://ollama.com/
# 2. In your Terminal, type 'ollama pull <model_name>'
# 3. In your Terminal, type ollama 'run <model_name>': You now have a chatbot that runs locally on your machine!
# 4. If you don't just want a chatbot, but perform some systematic tasks, you may want to check out Ollama for Python 'pip install ollama' (https://github.com/ollama/ollama-python) or the code below. When you run code in Python, it will connect to your locally run LLM, so all the advantages of running LLMs locally still apply
#
# ### Open AI
# Open AI allows access to its various models through a super easy to use API.
# 1. Buy API credits @ https://platform.openai.com/
# 2. Download API key and set as environment variable
# 3. Install OpenAI's package: 'pip install openai'
# 4. Also check out OpenAI's API tutorials (https://platform.openai.com/docs/quickstart).
#
# There are many additional packages that give you an integrated interface for accessing various LLMs. Langchain packages are especially useful (https://github.com/langchain-ai/langchain).

# %%
import ollama #Ollama python library
from openai import OpenAI #OpenAI Python library

import pandas as pd
import time
import json
import os

#lists of distinct aggravating and mitigating circumstances used for classification
from mitigating_aggravating_ai_lists import aggravating_list, mitigating_list

# %% [markdown]
# ## The scenario
# This workshop builds on a real-world (ongoing) investigation into potential bias in the Norwegian criminal justice system. It builds on work by Christian Nicolai and Henrik Bøe.
#
# In order to analyze whether decisions are fair, we need to compare similar criminal cases. A key factor in determining the severity of punishment is the presence or absence of mitigating and aggravating circumstances. But we have thousands of cases and not enough people power to hand code all the cases. So we thought, maybe a LLM can get the job done for us.
#
# The task is pretty straightforward: We have 'test_set' (paragraphs from judgements with mitigating/aggravating circumstances as well as labels) and aggravating_list as well as mitigating_list (unique aggravating/mitigating circumstances, each corresponding rougly to a letter in the Norwegian criminal code). The LLM's task is to figure out which, if any, aggravating or mitigating circumstance applies to each paragraph.
#
# Because the investigation is ongoing, and due to privacy concerns, we cannot share the underlying data for this analysis. But you can use this notebook as a template for your own classification tasks.

# %%
test_set = pd.read_csv('../data/test_set.csv', index_col='Unnamed: 0') #load test_data
test_set.head() # show test_data
# Out:
#    id         type                                               text  \
# 1   2   mitigating  LE-2017 -68515 concerned a pair of parents, or...
# 2   2   mitigating  The court cannot see that there are mitigating...
# 3   3  aggravating  When assessing the punishment for item I a) an...
# 4   3  aggravating  The court finds that items I b) and c), as wel...
# 5   3  aggravating  In this assessment, the court has taken into a...
#
#                                      hand_coded
# 1                                         other
# 2                                         FALSE
# 3  multiple crimes grouped into single sentence
# 4  multiple crimes grouped into single sentence
# 5                                  intoxication

# %%
# for the Open AI API to work, you need to set your API key as an environment variable.
os.environ["OPENAI_API_KEY"] = "your_OpenAI_API key"

# %%
# starts an OpenAI client
client = OpenAI()

# %%
# Systems prompts give LLMs a 'role' to play. In our case, we instruct the LLM to classify the judgements, 
# the formatting of the response, and the unique aggravating/mitigating circumstances
systems_prompt_aggravating = """You are an assistant who reads short text extracts from judgements. You must decide whether the text contains information about any aggravating circumstances in the case. You must identify the most relevant aggravating circumstance from the list below and enter it in JSON format in English.
You must only mention circumstances that are aggravating for this sentence, not circumstances for previous sentences. If it does not say that the circumstance is aggravating or if the text about the circumstance is written in the past tense, you must answer {"aggravating": "false"}.
You must answer in json format in English in this way: {"aggravating": "death threats"}. Name only one aggravating circumstance, the one you think is most important.
If you do not find a relevant circumstance in the list, answer {"aggravating": "other circumstances"}. If information about aggravating circumstances is missing, or if you are unable to interpret it, answer {"aggravating": "false"}.
If the wording of the circumstance is written in the past tense, for example "it was aggravating" or "it was aggravating", answer {"aggravating": "false"}.
Here is the list:
"""+aggravating_list

systems_prompt_mitigating = """You are an assistant who reads short text extracts from judgements. You must decide whether the text contains information about any mitigating circumstances in the case. You must identify the most relevant mitigating circumstance from the list below and enter it in JSON format in English.
You must only mention circumstances that are stated to be mitigating for this case, not circumstances that are mitigating for previous court cases. If it does not say that the circumstance is mitigating, or if the text about the circumstance is written in the past tense, you must answer {"mitigating": "false"}.
You must respond in json format in English in this way: {"mitigating": "self defense"}. Name only one mitigating circumstance, the one you think is the most important.
If you do not find a relevant circumstance in the list, answer {"mitigating": "other circumstances"}. If information about mitigating circumstances is missing or if you are unable to interpret it, answer {"mitigating": "false"}.
If the wording of the circumstance is written in the past tense, for example "it was mitigating" or "there was mitigating", answer {"mitigating": "false"}.
Here is the list:
"""+mitigating_list

# %% [markdown]
# ## Customizing your API calls
# Using APIs gives you more control over the LLMs behavior than just using an online chatbot. There are a couple of parameters, you want to pay especially close attention to:
# 1. The model you are using
# 2. Role: 'system' prompts allow you to give general behavioral instructions to the LLM. 'user' prompts are the actual messages the LLM respond to.
# 3. Seed: Setting a seed makes the model's output reproducible (as long as it doesn't change). Pick any number.
# 4. Temperature: how 'creative' should the LLM be. For most tasks you will want to set the temperature to zero.
#
# The full list of parameters for Ollama and GPT are available here: https://pypi.org/project/ollama-python/ and here: https://platform.openai.com/docs/api-reference/chat/create
#
# If you want to get fancy, you can also look into training a custom LLM or optimizing your local LLM's performance.

# %%
test_set_classified = [] #results data frame
my_seed = 9999 #seed

#loop over each row in the data frame
for index, row in test_set.iterrows():
    
    ### SET UP SYSTEMS PROMPT
    systems_prompt = ""
    if row['type'] == 'mitigating':
        systems_prompt = systems_prompt_mitigating
    else:
        systems_prompt = systems_prompt_aggravating
    
    ### OLLAMA ###
    start_llama = time.time() # measure start time
    response_llama = ollama.chat(model='llama3', #specify model
                                 messages=[
      {
        'role': 'system', # systems prompt
        'content': systems_prompt,
      },{
          'role' : 'user', # user prompt (the actual judgement paragraph)
          'content' : row['text']
      }
    ], options={
            'seed' : my_seed, # set seed
            'temperature' : 0 # set temperature
        }
    )
    end_llama = time.time() # measure end time
    time_llama = end_llama - start_llama #calculate run time
    row['time_llama'] = time_llama #save run time
    #extract Llama response
    try:
        response_llama_json = json.loads(response_llama['message']['content'])
        response_llama_json_keys = list(response_llama_json.keys())
        response_llama_json_values = list(response_llama_json.values())
    except:
        print('Llama did not return JSON')
        test_set_classified.append(row)
        next
    #ensure that response is well formatted
    if (not(len(response_llama_json_keys) == 1 and response_llama_json_keys[0] == row['type'])):
        print('JSON Llama output for index:', index, 'not well formatted')
        next
    #save response
    row['llama'] = response_llama_json_values[0]
    
    
    ### OPEN AI ###
    start_gpt = time.time() #measure start time
    response_gpt35 = client.chat.completions.create(
      model="gpt-3.5-turbo", # specify model
      response_format={ "type": "json_object" },  #specify response type
      messages=[
        {'role': 'system', 'content': systems_prompt}, #systems prompt
        {'role': 'user', 'content': row['text']} #user prompt (the actual judgement paragraph)
      ],
        seed=my_seed, # set seed
        temperature=0 # set temperature
    )
    end_gpt = time.time() # measure end time
    time_gpt = end_gpt - start_gpt #calculate run time
    row['time_gpt'] = time_gpt # save run time
    
    # extract openai response
    try:
        response_gpt35_json = json.loads(response_gpt35.choices[0].message.content)
        response_gpt35_json_keys = list(response_gpt35_json.keys())
        response_gpt35_json_values = list(response_gpt35_json.values())
    except:
        print('GPT did not return JSON')
        test_set_classified.append(row)
        next
    # ensure that response is well formatted
    if (not(len(response_gpt35_json_keys) == 1 and response_gpt35_json_keys[0] == row['type'])):
        print('JSON GPT 3.5 output for index:', index, 'not well formatted')
        next
    # save response
    row['gpt35'] = response_gpt35_json_values[0]
    

    test_set_classified.append(row) # add new row to results list
    
    print(row)
# Out:
# id                                                            2
# type                                                 mitigating
# text          LE-2017 -68515 concerned a pair of parents, or...
# hand_coded                                                other
# time_llama                                             6.010967
# llama                                    young age of defendant
# time_gpt                                               0.750304
# gpt35                                   limited mental capacity
# Name: 1, dtype: object
# id                                                            2
# type                                                 mitigating
# text          The court cannot see that there are mitigating...
# hand_coded                                                FALSE
# time_llama                                             1.472724
# llama                                                     false
# time_gpt                                               0.700658
# gpt35                                                confession
# Name: 2, dtype: object
# id                                                            3
# type                                                aggravating
# text          When assessing the punishment for item I a) an...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             5.812534
# llama              multiple crimes grouped into single sentence
# time_gpt                                               0.688785
# gpt35                                          repeated offense
# Name: 3, dtype: object
# id                                                            3
# type                                                aggravating
# text          The court finds that items I b) and c), as wel...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             1.685954
# llama              multiple crimes grouped into single sentence
# time_gpt                                               1.011522
# gpt35              multiple crimes grouped into single sentence
# Name: 4, dtype: object
# id                                                            3
# type                                                aggravating
# text          In this assessment, the court has taken into a...
# hand_coded                                         intoxication
# time_llama                                              3.75493
# llama         vulnerable victim, underaged victim, victim de...
# time_gpt                                               0.998499
# gpt35                  driving related aggravating circumstance
# Name: 5, dtype: object
# id                                                            3
# type                                                 mitigating
# text          In mitigating circumstances, the court emphasi...
# hand_coded                     long processing time; confession
# time_llama                                             3.832227
# llama                                       other circumstances
# time_gpt                                               0.812707
# gpt35                                                confession
# Name: 6, dtype: object
# Llama did not return JSON
# JSON Llama output for index: 7 not well formatted
# id                                                            5
# type                                                aggravating
# text          Section 155 of the Criminal Code has penalties...
# hand_coded                 risk to life or health of the victim
# time_llama                                            12.223583
# llama                                       other circumstances
# time_gpt                                               1.032402
# gpt35                      risk to life or health of the victim
# Name: 7, dtype: object
# id                                                            6
# type                                                aggravating
# text          In this case, the degree of influence alone di...
# hand_coded                                     repeated offense
# time_llama                                             2.649855
# llama         previous punishment for driving under influenc...
# time_gpt                                               0.860519
# gpt35                   drugs related aggravating circumstances
# Name: 8, dtype: object
# id                                                            6
# type                                                aggravating
# text          Øvergård must also be sentenced to loss of the...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             2.922151
# llama                   drugs related aggravating circumstances
# time_gpt                                               1.191982
# gpt35                                              intoxication
# Name: 9, dtype: object
# id                                                            6
# type                                                 mitigating
# text          In mitigation, emphasis must be placed on the ...
# hand_coded                                 long processing time
# time_llama                                             5.481238
# llama                                      long processing time
# time_gpt                                               0.778199
# gpt35                                      long processing time
# Name: 10, dtype: object
# id                                                            7
# type                                                 mitigating
# text          There are no mitigating circumstances in the c...
# hand_coded                                                FALSE
# time_llama                                             1.705068
# llama                                                     false
# time_gpt                                               0.500401
# gpt35                                                     false
# Name: 11, dtype: object
# id                                                            9
# type                                                 mitigating
# text          In mitigation, the court emphasizes that the d...
# hand_coded                     confession; long processing time
# time_llama                                              2.08031
# llama                                                confession
# time_gpt                                               1.172961
# gpt35                                                confession
# Name: 12, dtype: object
# id                                                           10
# type                                                aggravating
# text          The drug offense in item II and the road traff...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                              4.33756
# llama                                                     other
# time_gpt                                               0.675478
# gpt35                  driving related aggravating circumstance
# Name: 13, dtype: object
# id                                                           10
# type                                                aggravating
# text          The court assumes that the level of punishment...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             3.325212
# llama                                    general risk of spread
# time_gpt                                               0.853363
# gpt35                   drugs related aggravating circumstances
# Name: 14, dtype: object
# id                                                           10
# type                                                aggravating
# text          Driving with a high level of intoxication abov...
# hand_coded                                     repeated offense
# time_llama                                              2.69528
# llama                                          repeated offense
# time_gpt                                               0.566965
# gpt35                                              intoxication
# Name: 15, dtype: object
# id                                                           10
# type                                                aggravating
# text          When, as aggravating factors, items I and IV a...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             1.677013
# llama              multiple crimes grouped into single sentence
# time_gpt                                               0.878025
# gpt35                       weapon used or present during crime
# Name: 16, dtype: object
# Llama did not return JSON
# id                                                           11
# type                                                aggravating
# text            - 3 - 21-153912MED -TVIN/TGJO The court's as...
# hand_coded                                     repeated offense
# time_llama                                            17.389808
# llama              multiple crimes grouped into single sentence
# time_gpt                                               0.931248
# gpt35                                          repeated offense
# Name: 17, dtype: object
# id                                                           13
# type                                                aggravating
# text          Violence against the police entails as a start...
# hand_coded    multiple crimes grouped into single sentence; ...
# time_llama                                             4.866497
# llama                                          repeated offense
# time_gpt                                                0.83072
# gpt35                                          repeated offense
# Name: 18, dtype: object
# id                                                           13
# type                                                aggravating
# text          The court continues to look at the physical vi...
# hand_coded                 risk to life or health of the victim
# time_llama                                             2.395146
# llama                                          repeated offense
# time_gpt                                               0.797411
# gpt35                      risk to life or health of the victim
# Name: 19, dtype: object
# id                                                           13
# type                                                aggravating
# text          Carrying a knife is a penalty that must be wei...
# hand_coded                  weapon used or present during crime
# time_llama                                             1.419792
# llama                       weapon used or present during crime
# time_gpt                                               0.704002
# gpt35                       weapon used or present during crime
# Name: 20, dtype: object
# id                                                           13
# type                                                 mitigating
# text          Overall, the court believes that the condition...
# hand_coded                                           confession
# time_llama                                             4.035555
# llama                                                confession
# time_gpt                                               1.096929
# gpt35                                                confession
# Name: 21, dtype: object
# id                                                           15
# type                                                aggravating
# text          It is the 3 physical violations in item I of t...
# hand_coded                 risk to life or health of the victim
# time_llama                                             6.221552
# llama                      risk to life or health of the victim
# time_gpt                                               1.116226
# gpt35                      risk to life or health of the victim
# Name: 22, dtype: object
# id                                                           15
# type                                                aggravating
# text          General preventive considerations justify a st...
# hand_coded    vulnerable victim, underaged victim, victim de...
# time_llama                                             2.950082
# llama                                          repeated offense
# time_gpt                                               0.788608
# gpt35                   drugs related aggravating circumstances
# Name: 23, dtype: object
# id                                                           15
# type                                                 mitigating
# text          There are no mitigating circumstances in the c...
# hand_coded                                                FALSE
# time_llama                                             3.230003
# llama                                                     false
# time_gpt                                               0.919217
# gpt35                                                     false
# Name: 24, dtype: object
# Llama did not return JSON
# JSON Llama output for index: 25 not well formatted
# id                                                           17
# type                                                aggravating
# text          There are several aggravating factors. The cou...
# hand_coded    vulnerable victim, underaged victim, victim de...
# time_llama                                             8.546143
# llama                                                     false
# time_gpt                                               0.860311
# gpt35                      risk to life or health of the victim
# Name: 25, dtype: object
# id                                                           17
# type                                                aggravating
# text          It is further aggravating that parts of the vi...
# hand_coded                                     children present
# time_llama                                             2.224915
# llama                                          children present
# time_gpt                                               0.886331
# gpt35                                          children present
# Name: 26, dtype: object
# id                                                           17
# type                                                aggravating
# text          In the court's view, the use of jumping rope i...
# hand_coded                  weapon used or present during crime
# time_llama                                             2.092444
# llama               use of jumping rope in exercise of violence
# time_gpt                                               0.634159
# gpt35                       weapon used or present during crime
# Name: 27, dtype: object
# id                                                           17
# type                                                 mitigating
# text          Taking aggravating circumstances into account,...
# hand_coded                                                FALSE
# time_llama                                             3.469634
# llama                                                     false
# time_gpt                                               0.738711
# gpt35                                                     false
# Name: 28, dtype: object
# id                                                           17
# type                                                 mitigating
# text          Of mitigating circumstances, the court points ...
# hand_coded                                                FALSE
# time_llama                                              3.10695
# llama                        self-defense or provoked by victim
# time_gpt                                               0.938576
# gpt35                        self-defense or provoked by victim
# Name: 29, dtype: object
# id                                                           17
# type                                                 mitigating
# text          In mitigation, however, the court points out t...
# hand_coded                                 long processing time
# time_llama                                             1.966146
# llama                                      long processing time
# time_gpt                                               0.754553
# gpt35                                      long processing time
# Name: 30, dtype: object
# id                                                           17
# type                                                 mitigating
# text          The court finds that the sentence should be ap...
# hand_coded                                                FALSE
# time_llama                                             1.601942
# llama                                       other circumstances
# time_gpt                                               0.844521
# gpt35                                                     other
# Name: 31, dtype: object
# id                                                           18
# type                                                aggravating
# text          The court notes that the threats against journ...
# hand_coded    vulnerable victim, underaged victim, victim de...
# time_llama                                             5.421833
# llama                                                hate crime
# time_gpt                                               0.579022
# gpt35                                                   threats
# Name: 32, dtype: object
# id                                                           18
# type                                                aggravating
# text          Section 79 letter a of the Criminal Code appli...
# hand_coded                                     repeated offense
# time_llama                                             1.946537
# llama                                          repeated offense
# time_gpt                                               0.939189
# gpt35                                          repeated offense
# Name: 33, dtype: object
# id                                                           18
# type                                                 mitigating
# text          Neurological specialist statement of 05.01.202...
# hand_coded                                                FALSE
# time_llama                                             4.088214
# llama                                                     false
# time_gpt                                               0.822137
# gpt35                                   limited mental capacity
# Name: 34, dtype: object
# id                                                           18
# type                                                 mitigating
# text          The defendant's health situation is not consid...
# hand_coded                                                FALSE
# time_llama                                             0.995363
# llama                                                     false
# time_gpt                                                0.58342
# gpt35                                                     false
# Name: 35, dtype: object
# id                                                18
# type                                      mitigating
# text          There are no mitigating circumstances.
# hand_coded                                     FALSE
# time_llama                                   1.51256
# llama                                          false
# time_gpt                                     0.61344
# gpt35                                          false
# Name: 36, dtype: object
# id                                                           19
# type                                                 mitigating
# text          In accordance with the draft law and case law,...
# hand_coded                                                FALSE
# time_llama                                             1.717718
# llama                                                     false
# time_gpt                                               0.967121
# gpt35                                   limited mental capacity
# Name: 37, dtype: object
# id                                                           19
# type                                                 mitigating
# text          The court cannot see that there are any specia...
# hand_coded                                                FALSE
# time_llama                                              1.00182
# llama                                                     false
# time_gpt                                               0.760517
# gpt35                                                     false
# Name: 38, dtype: object
# id                                                           19
# type                                                 mitigating
# text          If a defendant has exceeded the limit for emer...
# hand_coded                                                FALSE
# time_llama                                              1.99059
# llama                                                     false
# time_gpt                                               0.770722
# gpt35                                                     other
# Name: 39, dtype: object
# id                                                           21
# type                                                 mitigating
# text          The sentencing must take place on the basis of...
# hand_coded                                                FALSE
# time_llama                                             1.549357
# llama                                       other circumstances
# time_gpt                                               0.977467
# gpt35                                                     other
# Name: 40, dtype: object
# id                                                           21
# type                                                 mitigating
# text          In mitigation, emphasis must be placed on the ...
# hand_coded                                           confession
# time_llama                                             1.928526
# llama                        self-defense or provoked by victim
# time_gpt                                               0.796846
# gpt35                           defendant made amends for crime
# Name: 41, dtype: object
# id                                                           21
# type                                                 mitigating
# text          Emphasis is also placed on the fact that he ha...
# hand_coded                                 long processing time
# time_llama                                             1.302963
# llama                                       other circumstances
# time_gpt                                               0.621649
# gpt35                                                     other
# Name: 42, dtype: object
# id                                                           21
# type                                                 mitigating
# text          The court cannot see that there are any mitiga...
# hand_coded                                                FALSE
# time_llama                                             0.986798
# llama                                                     false
# time_gpt                                               0.689165
# gpt35                                                     false
# Name: 43, dtype: object
# id                                                           21
# type                                                 mitigating
# text          In a mitigating way, Bradzeika already in Sept...
# hand_coded                                           confession
# time_llama                                             1.563272
# llama                                                confession
# time_gpt                                               0.991794
# gpt35                                                confession
# Name: 44, dtype: object
# id                                                           21
# type                                                 mitigating
# text          Furthermore, the court emphasizes that the rel...
# hand_coded                                 long processing time
# time_llama                                             2.908707
# llama         punishment would present psychological, physic...
# time_gpt                                               0.831639
# gpt35                                      long processing time
# Name: 45, dtype: object
# id                                                           21
# type                                                 mitigating
# text          The court cannot see that there are mitigating...
# hand_coded                                                FALSE
# time_llama                                             1.062556
# llama                                                     false
# time_gpt                                               0.892191
# gpt35                                                     false
# Name: 46, dtype: object
# id                                                           22
# type                                                aggravating
# text          In the mediator's direction, it is emphasized ...
# hand_coded    confession; punishment would present psycholog...
# time_llama                                             4.850804
# llama                                       other circumstances
# time_gpt                                               0.990099
# gpt35         vulnerable victim, underaged victim, victim de...
# Name: 47, dtype: object
# id                                                           22
# type                                                 mitigating
# text          The court has assessed whether it is aggravati...
# hand_coded    multiple crimes grouped into single sentence; ...
# time_llama                                             4.101287
# llama                                                     false
# time_gpt                                               1.056818
# gpt35                                   limited mental capacity
# Name: 48, dtype: object
# id                                                           23
# type                                                aggravating
# text          The defendant is an almost 29-year-old. In the...
# hand_coded                                     repeated offense
# time_llama                                             4.892401
# llama                                          repeated offense
# time_gpt                                               0.597961
# gpt35                                          repeated offense
# Name: 49, dtype: object
# id                                                           24
# type                                                aggravating
# text          In aggravating circumstances, the defendant wa...
# hand_coded             driving related aggravating circumstance
# time_llama                                             1.457929
# llama                  driving related aggravating circumstance
# time_gpt                                               0.575475
# gpt35                                         reckless behavior
# Name: 50, dtype: object
# id                                                      24
# type                                            mitigating
# text          The court finds no mitigating circumstances.
# hand_coded                                           FALSE
# time_llama                                        3.253213
# llama                                                false
# time_gpt                                          0.736106
# gpt35                                                false
# Name: 51, dtype: object
# id                                                           26
# type                                                aggravating
# text          The court assumes that the most serious relati...
# hand_coded    multiple crimes grouped into single sentence; ...
# time_llama                                             4.064659
# llama                                                     false
# time_gpt                                               0.804442
# gpt35                                          repeated offense
# Name: 52, dtype: object
# id                                                           26
# type                                                aggravating
# text          \nFurthermore, the violation in item III (unau...
# hand_coded                           violation of private place
# time_llama                                             1.851017
# llama                                violation of private place
# time_gpt                                               0.845909
# gpt35                                violation of private place
# Name: 53, dtype: object
# id                                                           26
# type                                                aggravating
# text          Furthermore, the violation in item III (unauth...
# hand_coded                           violation of private place
# time_llama                                             1.857979
# llama                                violation of private place
# time_gpt                                               0.882513
# gpt35                                violation of private place
# Name: 54, dtype: object
# id                                                           26
# type                                                aggravating
# text          The thefts in item IV b -d and f) as well as t...
# hand_coded    multiple crimes grouped into single sentence; ...
# time_llama                                             1.662954
# llama              multiple crimes grouped into single sentence
# time_gpt                                               0.821645
# gpt35              multiple crimes grouped into single sentence
# Name: 55, dtype: object
# id                                                           26
# type                                                 mitigating
# text          The court does not find that there are any mit...
# hand_coded                                                FALSE
# time_llama                                             3.354004
# llama                                                     false
# time_gpt                                               0.662644
# gpt35                                                     false
# Name: 56, dtype: object
# id                                                           27
# type                                                 mitigating
# text          The defendant has acknowledged the relationshi...
# hand_coded                                                FALSE
# time_llama                                             1.469913
# llama                                                     false
# time_gpt                                                1.08175
# gpt35                                                confession
# Name: 57, dtype: object
# id                                                           28
# type                                                 mitigating
# text          In mitigation, the court places emphasis on th...
# hand_coded                                           confession
# time_llama                                             1.945184
# llama                                                confession
# time_gpt                                               0.856016
# gpt35                                                confession
# Name: 58, dtype: object
# id                                                           28
# type                                                 mitigating
# text          The court also emphasizes in mitigating the fa...
# hand_coded                                 long processing time
# time_llama                                             1.893673
# llama                                      long processing time
# time_gpt                                               0.578368
# gpt35                                      long processing time
# Name: 59, dtype: object
# id                                                           29
# type                                                aggravating
# text          Penalty A penalty shall be imposed for a breac...
# hand_coded    multiple crimes grouped into single sentence; ...
# time_llama                                             4.759936
# llama              multiple crimes grouped into single sentence
# time_gpt                                               0.702421
# gpt35              multiple crimes grouped into single sentence
# Name: 60, dtype: object
# id                                                           29
# type                                                 mitigating
# text          Furthermore, mitigating weight must be added t...
# hand_coded                                 long processing time
# time_llama                                             4.976099
# llama         violation of right to trial within a reasonabl...
# time_gpt                                               0.552689
# gpt35                                      long processing time
# Name: 61, dtype: object
# id                                                           30
# type                                                aggravating
# text          The court finds that the defendant must be sen...
# hand_coded    crime committed over long period of time, part...
# time_llama                                             4.869157
# llama                  crime committed over long period of time
# time_gpt                                                0.85447
# gpt35         crime committed over long period of time, part...
# Name: 62, dtype: object
# id                                                           30
# type                                                 mitigating
# text          The public prosecutor's office has proposed th...
# hand_coded                     confession; long processing time
# time_llama                                             5.108168
# llama                                      long processing time
# time_gpt                                               0.885016
# gpt35                                      long processing time
# Name: 63, dtype: object
# id                                                           30
# type                                                 mitigating
# text          As justification for the length of the sentenc...
# hand_coded                                 long processing time
# time_llama                                             2.691733
# llama                                      long processing time
# time_gpt                                               0.749457
# gpt35                                      long processing time
# Name: 64, dtype: object
# id                                                           31
# type                                                aggravating
# text          3 The court's assessment of the sentencing Whe...
# hand_coded    multiple crimes grouped into single sentence; ...
# time_llama                                             5.591339
# llama                                                   threats
# time_gpt                                               1.202747
# gpt35                                                   threats
# Name: 65, dtype: object
# id                                                           31
# type                                                 mitigating
# text          In addition, the court emphasized Section 78, ...
# hand_coded                              limited mental capacity
# time_llama                                             4.594898
# llama                                   limited mental capacity
# time_gpt                                               0.687383
# gpt35                                   limited mental capacity
# Name: 66, dtype: object
# Llama did not return JSON
# JSON Llama output for index: 67 not well formatted
# id                                                           32
# type                                                aggravating
# text          Regarding sentencing, it is noted: The evidenc...
# hand_coded                                      organized crime
# time_llama                                             8.779664
# llama                                   limited mental capacity
# time_gpt                                               0.959773
# gpt35                   drugs related aggravating circumstances
# Name: 67, dtype: object
# id                                                           34
# type                                                aggravating
# text          The court found that the normal punishment for...
# hand_coded                                                other
# time_llama                                             1.437073
# llama                                          repeated offense
# time_gpt                                               0.620454
# gpt35                                violation of private place
# Name: 68, dtype: object
# id                                                           34
# type                                                aggravating
# text          For comparison, the court shows Rt -2004 -1495...
# hand_coded                                      organized crime
# time_llama                                             1.763801
# llama                                                     false
# time_gpt                                                0.73829
# gpt35                                              premeditated
# Name: 69, dtype: object
# id                                                           34
# type                                                 mitigating
# text          Defense counsel has stated on behalf of Dura t...
# hand_coded    punishment would present psychological, physic...
# time_llama                                             4.742083
# llama         punishment would present psychological, physic...
# time_gpt                                               0.808772
# gpt35         punishment would present psychological, physic...
# Name: 70, dtype: object
# id                                                           34
# type                                                 mitigating
# text          Here, the legislator has primarily considered ...
# hand_coded    punishment would present psychological, physic...
# time_llama                                             3.139475
# llama                                       other circumstances
# time_gpt                                               1.046958
# gpt35         punishment would present psychological, physic...
# Name: 71, dtype: object
# id                                                           34
# type                                                 mitigating
# text          There are no other mitigating circumstances in...
# hand_coded                                                FALSE
# time_llama                                              1.20043
# llama                                                     false
# time_gpt                                               0.466906
# gpt35                                       other circumstances
# Name: 72, dtype: object
# id                                                           37
# type                                                aggravating
# text          An overall penalty must be imposed, cf. Penal ...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             4.413537
# llama                                                     false
# time_gpt                                                 0.7239
# gpt35                            violated relationship of trust
# Name: 73, dtype: object
# id                                                           37
# type                                                 mitigating
# text          In mitigation comes the defendant's unreserved...
# hand_coded                                           confession
# time_llama                                             3.607491
# llama                                                confession
# time_gpt                                               0.884494
# gpt35                                                confession
# Name: 74, dtype: object
# id                                                           38
# type                                                aggravating
# text          When sentencing, the attempted rape of a child...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             5.289514
# llama         vulnerable victim, underaged victim, victim de...
# time_gpt                                               0.868336
# gpt35         vulnerable victim, underaged victim, victim de...
# Name: 75, dtype: object
# Llama did not return JSON
# id                                                           38
# type                                                aggravating
# text          When sentencing, account must also be taken of...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             5.686865
# llama         vulnerable victim, underaged victim, victim de...
# time_gpt                                                0.94512
# gpt35         vulnerable victim, underaged victim, victim de...
# Name: 76, dtype: object
# id                                                           38
# type                                                 mitigating
# text          In mitigation, consideration must be given to ...
# hand_coded                                 long processing time
# time_llama                                             3.929006
# llama                                      long processing time
# time_gpt                                               0.566695
# gpt35                                      long processing time
# Name: 77, dtype: object
# id                                                           39
# type                                                aggravating
# text          In the direction of increasing penalties, the ...
# hand_coded                                     repeated offense
# time_llama                                             4.199647
# llama                                          repeated offense
# time_gpt                                               0.866195
# gpt35                                          repeated offense
# Name: 78, dtype: object
# id                                                           39
# type                                                 mitigating
# text          In a mitigating way, emphasis must be placed o...
# hand_coded                                 long processing time
# time_llama                                             3.920543
# llama                                      long processing time
# time_gpt                                               0.920936
# gpt35                                      long processing time
# Name: 79, dtype: object
# id                                                           41
# type                                                aggravating
# text          In the previous judgment, the court emphasized...
# hand_coded    vulnerable victim, underaged victim, victim de...
# time_llama                                             6.946263
# llama         vulnerable victim, underaged victim, victim de...
# time_gpt                                               0.996647
# gpt35         vulnerable victim, underaged victim, victim de...
# Name: 80, dtype: object
# id                                                           41
# type                                                aggravating
# text          Strl Section 77 k) stipulates that, in an aggr...
# hand_coded                                     repeated offense
# time_llama                                             1.417902
# llama                               previous criminal sanctions
# time_gpt                                               0.521691
# gpt35                                          repeated offense
# Name: 81, dtype: object
# id                                                           41
# type                                                aggravating
# text          Both mother and daughter have experienced the ...
# hand_coded    vulnerable victim, underaged victim, victim de...
# time_llama                                              2.58952
# llama                                violation of private place
# time_gpt                                               0.870421
# gpt35                                violation of private place
# Name: 82, dtype: object
# id                                                           41
# type                                                 mitigating
# text          Although the defendant has no recollection of ...
# hand_coded                                           confession
# time_llama                                             3.823757
# llama                                       other circumstances
# time_gpt                                               0.886305
# gpt35                                                confession
# Name: 83, dtype: object
# id                                                           42
# type                                                 mitigating
# text          The defendant has not admitted criminal guilt ...
# hand_coded                                           confession
# time_llama                                             1.713608
# llama                                contribution to disclosure
# time_gpt                                               0.899387
# gpt35                                                confession
# Name: 84, dtype: object
# Llama did not return JSON
# JSON Llama output for index: 85 not well formatted
# id                                                           43
# type                                                aggravating
# text          The present case concerns the payment of bills...
# hand_coded                                     repeated offense
# time_llama                                            12.866563
# llama                                contribution to disclosure
# time_gpt                                               0.996249
# gpt35                                          repeated offense
# Name: 85, dtype: object
# id                                                           44
# type                                                aggravating
# text           It concerns unprovoked nightlife violence com...
# hand_coded                 risk to life or health of the victim
# time_llama                                              3.42207
# llama         vulnerable victim, underaged victim, victim de...
# time_gpt                                               0.664591
# gpt35         vulnerable victim, underaged victim, victim de...
# Name: 86, dtype: object
# id                                                           44
# type                                                 mitigating
# text          The fact that the defendant himself, due to se...
# hand_coded                                                FALSE
# time_llama                                              6.06799
# llama                                                     false
# time_gpt                                               0.684067
# gpt35                        self-defense or provoked by victim
# Name: 87, dtype: object
# id                                                           44
# type                                                 mitigating
# text          Punishment for bodily harm is a fine or impris...
# hand_coded                                           confession
# time_llama                                             4.834911
# llama                                                confession
# time_gpt                                               0.584187
# gpt35                                                confession
# Name: 88, dtype: object
# id                                                           46
# type                                                aggravating
# text          Prison It is the violation of the Road Traffic...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             4.831695
# llama              multiple crimes grouped into single sentence
# time_gpt                                               0.691429
# gpt35                  driving related aggravating circumstance
# Name: 89, dtype: object
# id                                                           46
# ...
# time_llama                                             5.794096
# llama                  driving related aggravating circumstance
# time_gpt                                               1.085484
# gpt35                      risk to life or health of the victim
# Name: 125, dtype: object
# id                                                           61
# type                                                aggravating
# text          The hastihetsov finding in the indictment item...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             2.050078
# llama                                       other circumstances
# time_gpt                                               0.881406
# gpt35                   drugs related aggravating circumstances
# Name: 126, dtype: object
# id                                                           61
# type                                                 mitigating
# text          The court has come to the conclusion that the ...
# hand_coded                         potential for rehabilitation
# time_llama                                             4.321675
# llama                              potential for rehabilitation
# time_gpt                                               0.596166
# gpt35                              potential for rehabilitation
# Name: 127, dtype: object
# id                                                           61
# type                                                 mitigating
# text          In mitigation, emphasis is placed on the accus...
# hand_coded                                           confession
# time_llama                                             1.551611
# llama                                                confession
# time_gpt                                               1.179891
# gpt35                                                confession
# Name: 128, dtype: object
# id                                                           61
# type                                                 mitigating
# text          Furthermore, the long time that has passed sin...
# hand_coded                                 long processing time
# time_llama                                             1.906274
# llama                                      long processing time
# time_gpt                                               0.631128
# gpt35                                      long processing time
# Name: 129, dtype: object
# id                                                           62
# type                                                aggravating
# text          It is aggravating that the defendant hit the v...
# hand_coded                 risk to life or health of the victim
# time_llama                                              4.48423
# llama                                          repeated offense
# time_gpt                                               0.626135
# gpt35                      risk to life or health of the victim
# Name: 130, dtype: object
# id                                                           62
# type                                                 mitigating
# text          "Very many, and in some cases unequal, methods...
# hand_coded                                                FALSE
# time_llama                                             6.462432
# llama                                                     false
# time_gpt                                               0.827271
# gpt35                        self-defense or provoked by victim
# Name: 131, dtype: object
# id                                                           62
# type                                                 mitigating
# text          The defendant's difficult upbringing, the negl...
# hand_coded                              limited mental capacity
# time_llama                                             1.435384
# llama                                   limited mental capacity
# time_gpt                                               0.857017
# gpt35                                   limited mental capacity
# Name: 132, dtype: object
# id                                                           62
# type                                                 mitigating
# text          Furthermore, it is mitigating that the defenda...
# hand_coded                                           confession
# time_llama                                             1.591623
# llama                                                confession
# time_gpt                                               0.707912
# gpt35                                                confession
# Name: 133, dtype: object
# id                                                           63
# type                                                aggravating
# text          Items III, V and VI constitute fines and tend ...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             4.668476
# llama                      risk to life or health of the victim
# time_gpt                                               1.216832
# gpt35                       weapon used or present during crime
# Name: 134, dtype: object
# id                                                           63
# type                                                aggravating
# text          Furthermore, it follows from the loss regulati...
# hand_coded                                                other
# time_llama                                             2.781127
# llama                        prevention of police investigation
# time_gpt                                               0.816973
# gpt35                                         reckless behavior
# Name: 135, dtype: object
# id                                                           63
# type                                                 mitigating
# text          In mitigation, the defendant's confession in c...
# hand_coded                     confession; long processing time
# time_llama                                              4.23359
# llama                                      long processing time
# time_gpt                                               0.676259
# gpt35                                                confession
# Name: 136, dtype: object
# id                                                           63
# type                                                 mitigating
# text          In mitigating circumstances, the defendant's c...
# hand_coded                                           confession
# time_llama                                             1.313686
# llama                                                confession
# time_gpt                                               0.697363
# gpt35                                                confession
# Name: 137, dtype: object
# id                                                           63
# type                                                 mitigating
# text          After deductions for mitigating circumstances,...
# hand_coded                                 long processing time
# time_llama                                             1.237862
# llama                                                     false
# time_gpt                                                1.73721
# gpt35                                                     other
# Name: 138, dtype: object
# id                                                           65
# type                                                aggravating
# text          When sentencing, the court must take the most ...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             5.294726
# llama                                                     false
# time_gpt                                               0.981164
# gpt35                  driving related aggravating circumstance
# Name: 139, dtype: object
# id                                                           66
# type                                                aggravating
# text          When assessing the penalty, special considerat...
# hand_coded             driving related aggravating circumstance
# time_llama                                              2.61103
# llama                                violation of private place
# time_gpt                                               1.148238
# gpt35                      risk to life or health of the victim
# Name: 140, dtype: object
# id                                                           66
# type                                                aggravating
# text          Driving for the third time without a valid dri...
# hand_coded                                                FALSE
# time_llama                                             1.685389
# llama                                          repeated offense
# time_gpt                                               0.561907
# gpt35                                          repeated offense
# Name: 141, dtype: object
# id                                                           66
# type                                                aggravating
# text          After an overall assessment of Jacobsen's fina...
# hand_coded             driving related aggravating circumstance
# time_llama                                             2.772179
# llama                                                     false
# time_gpt                                                0.99858
# gpt35                                         reckless behavior
# Name: 142, dtype: object
# id                                                           67
# type                                                aggravating
# text          Taking into account that the first driving too...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                             2.415501
# llama                  driving related aggravating circumstance
# time_gpt                                                0.60935
# gpt35                  driving related aggravating circumstance
# Name: 143, dtype: object
# id                                                           67
# type                                                 mitigating
# text          One case of driving with a blood alcohol level...
# hand_coded                                                FALSE
# time_llama                                             4.822288
# llama                                                     false
# time_gpt                                               0.764559
# gpt35                                    no previous conviction
# Name: 144, dtype: object
# id                                                           67
# type                                                 mitigating
# text          The defendant has made unreserved confessions ...
# hand_coded                                           confession
# time_llama                                             3.442395
# llama                                                confession
# time_gpt                                               0.664829
# gpt35                                                confession
# Name: 145, dtype: object
# id                                                           70
# type                                                 mitigating
# text          It is the robbery in post I that is the most s...
# hand_coded                                           confession
# time_llama                                             2.091442
# llama                                                confession
# time_gpt                                               0.521902
# gpt35                                                confession
# Name: 146, dtype: object
# id                                                           70
# type                                                 mitigating
# text          The car theft of the trailer in item II qualif...
# hand_coded           minor crime or minor role of the defendant
# time_llama                                             2.323554
# llama                                       other circumstances
# time_gpt                                               1.524656
# gpt35                                   limited mental capacity
# Name: 147, dtype: object
# id                                                           71
# type                                                aggravating
# text          It follows from the Road Traffic Act Section 3...
# hand_coded             driving related aggravating circumstance
# time_llama                                             4.908951
# llama                                              intoxication
# time_gpt                                                0.66708
# gpt35                                              intoxication
# Name: 148, dtype: object
# id                                                           71
# type                                                 mitigating
# text          In mitigation, the court emphasized that the d...
# hand_coded                                           confession
# time_llama                                             3.900414
# llama                                                confession
# time_gpt                                               0.550232
# gpt35                                                confession
# Name: 149, dtype: object
# id                                                           73
# type                                                 mitigating
# text          In an aggravating way, it is emphasized that t...
# hand_coded                     confession, long processing time
# time_llama                                             2.169655
# llama                                      long processing time
# time_gpt                                               2.345208
# gpt35                                      long processing time
# Name: 150, dtype: object
# id                                                           74
# type                                                aggravating
# text          In the case of repeated driving while under th...
# hand_coded                                     repeated offense
# time_llama                                              5.21535
# llama                                          repeated offense
# time_gpt                                               0.509853
# gpt35                                              intoxication
# Name: 151, dtype: object
# id                                                           74
# type                                                 mitigating
# text          In mitigation, it is emphasized that there has...
# hand_coded                                 long processing time
# time_llama                                             3.671549
# llama                                      long processing time
# time_gpt                                               2.082155
# gpt35                                      long processing time
# Name: 152, dtype: object
# Llama did not return JSON
# JSON Llama output for index: 153 not well formatted
# id                                                           75
# type                                                aggravating
# text          In our case, however, it is aggravating that t...
# hand_coded         multiple crimes grouped into single sentence
# time_llama                                              9.33078
# llama                                      long processing time
# time_gpt                                                0.69168
# gpt35                  driving related aggravating circumstance
# Name: 153, dtype: object
# Llama did not return JSON
# id                                                           75
# type                                                 mitigating
# text          In a mitigating way, it must be taken into acc...
# hand_coded                     confession; long processing time
# time_llama                                            10.285356
# llama                                      long processing time
# time_gpt                                               0.881045
# gpt35                                                confession
# Name: 154, dtype: object

# %%
test_set_classified = pd.DataFrame(test_set_classified) #convert results list to pandas dataframe
test_set_classified.head()
# Out:
#    id         type                                               text  \
# 1   2   mitigating  LE-2017 -68515 concerned a pair of parents, or...
# 2   2   mitigating  The court cannot see that there are mitigating...
# 3   3  aggravating  When assessing the punishment for item I a) an...
# 4   3  aggravating  The court finds that items I b) and c), as wel...
# 5   3  aggravating  In this assessment, the court has taken into a...
#
#                                      hand_coded  time_llama  \
# 1                                         other    6.010967
# 2                                         FALSE    1.472724
# 3  multiple crimes grouped into single sentence    5.812534
# 4  multiple crimes grouped into single sentence    1.685954
# 5                                  intoxication    3.754930
#
#                                                llama  time_gpt  \
# 1                             young age of defendant  0.750304
# 2                                              false  0.700658
# 3       multiple crimes grouped into single sentence  0.688785
# 4       multiple crimes grouped into single sentence  1.011522
# 5  vulnerable victim, underaged victim, victim de...  0.998499
#
#                                           gpt35
# 1                       limited mental capacity
# 2                                    confession
# 3                              repeated offense
# 4  multiple crimes grouped into single sentence
# 5      driving related aggravating circumstance

# %%
test_set_classified.to_csv('../data/test_set_classified.csv') #save results data frame
